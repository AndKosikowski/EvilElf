# %%
import pandas as pd
import argparse
import os
import math
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# #python3 dataframe_creator.py --benignware ../Labeled-Elfs-main/benignware/ --malware ../Labeled-Elfs-main/malware

# %%
def read_directory(directory_path, is_malware):
    files = os.listdir(directory_path)
    list_df = []
    for file in files:
        file_path = os.path.join(directory_path, file)
        if os.path.isfile(file_path):
            row = create_file_row(file_path, is_malware) 
            list_df.append(row)
    return pd.DataFrame(data = list_df, columns=['name','is_malware','size','architecture','address_size','endianness','ABI','compiler_used','optimization_level','obfuscation','stripped','package','program'])

# %%
def create_file_row(file_path, is_malware):
    row = []
    base_name = os.path.basename(file_path)
    size = os.path.getsize(file_path)
    split = base_name.split("__")
    row.append(base_name)
    row.append(is_malware)
    row.append(size)
    row.extend(split)
    return row

# %%
def reduce_non_malware_to_same_amount(dataframe):
    malware_total = dataframe['is_malware'].sum()
    count = 0
    to_drop = []
    for i,row in dataframe.iterrows():
        if row['is_malware'] == 0:
            if count < malware_total:
                count = count + 1
            else:
                to_drop.append(i)

    return dataframe.drop(index=to_drop, axis = 0).sample(frac=1)

# %%
parser = argparse.ArgumentParser("dataframe_creator")

parser.add_argument("--benignware", default = "../Labeled-Elfs-main/benignware/", help = "The path to a folder containing only benign ELF executables")
parser.add_argument("--malware", default = "../Labeled-Elfs-main/malware/", help = "The path to a folder containing only malware ELF executables")
parser.add_argument("--train_amount", default = 0.8, help = "Decimal fraction out of 1 to use for train split")
parser.add_argument("--test_amount", default = 0.1, help = "Decimal fraction out of 1 to use for test split")
parser.add_argument("--valid_amount", default = 0.1, help = "Decimal fraction out of 1 to use for validation split")
parser.add_argument("--num_to_use", help = "Number of entries from files to use, leave empty for whole dataset")

args = parser.parse_known_args()[0]

# %%
df1 = read_directory(args.benignware,0)
df2 = read_directory(args.malware,1)

# %%
combined_df = pd.concat([df1, df2], ignore_index=True)

combined_df = combined_df.sample(frac = 1,random_state=42069,ignore_index = True)
print(combined_df)
# Out:
#                                                     name  is_malware    size  \
# 0      x86__64__lsb__unix-system-v__gcc-9.3.0__O1__no...           0   36208
# 1      x86__64__lsb__unix-system-v__gcc-9.1.0__Os__no...           0   34184
# 2      x86__64__lsb__unix-system-v__gcc-4.9.0__O3__un...           0   67368
# 3      x86__64__lsb__unix-system-v__llvm-obfuscator-3...           0  225064
# 4      x86__64__lsb__unix-system-v__llvm-obfuscator-3...           0   60464
# ...                                                  ...         ...     ...
# 39964  x86__64__lsb__unix-system-v__gcc-7.1.0__O0__no...           0   26424
# 39965  x86__64__lsb__unix-system-v__llvm-obfuscator-4...           0   57168
# 39966  x86__64__lsb__unix-system-v__gcc-7.1.0__O3__no...           0   11280
# 39967  x86__64__lsb__unix-system-v__gcc-8.1.0__O2__no...           0   71744
# 39968  x86__64__lsb__unix-system-v__clang-3.9.0__O2__...           0   88752
#
#       architecture address_size endianness            ABI  \
# 0              x86           64        lsb  unix-system-v
# 1              x86           64        lsb  unix-system-v
# 2              x86           64        lsb  unix-system-v
# 3              x86           64        lsb  unix-system-v
# 4              x86           64        lsb  unix-system-v
# ...            ...          ...        ...            ...
# 39964          x86           64        lsb  unix-system-v
# 39965          x86           64        lsb  unix-system-v
# 39966          x86           64        lsb  unix-system-v
# 39967          x86           64        lsb  unix-system-v
# 39968          x86           64        lsb  unix-system-v
#
#                compiler_used optimization_level obfuscation        stripped  \
# 0                  gcc-9.3.0                 O1      no-obf      unstripped
# 1                  gcc-9.1.0                 Os      no-obf      unstripped
# 2                  gcc-4.9.0                 O3  unstripped  coreutils-8.30
# 3      llvm-obfuscator-3.6.1                 O0    mllvmsub      unstripped
# 4      llvm-obfuscator-3.6.1                 O2    mllvmbcf      unstripped
# ...                      ...                ...         ...             ...
# 39964              gcc-7.1.0                 O0      no-obf      unstripped
# 39965  llvm-obfuscator-4.0.1                 Os    mllvmbcf      unstripped
# 39966              gcc-7.1.0                 O3      no-obf      unstripped
# 39967              gcc-8.1.0                 O2      no-obf      unstripped
# 39968            clang-3.9.0                 O2      no-obf      unstripped
#
#                package    program
# 0       coreutils-8.30     whoami
# 1       coreutils-8.30       echo
# 2             realpath       None
# 3       coreutils-8.30  sha512sum
# 4      util-linux-2.33    setterm
# ...                ...        ...
# 39964  util-linux-2.33    addpart
# 39965   coreutils-8.30     printf
# 39966  util-linux-2.33     findfs
# 39967   coreutils-8.30       stty
# 39968   coreutils-8.30      touch
#
# [39969 rows x 13 columns]

# %%
combined_df.to_csv("Combined_ELF_Dataset.csv",index=False)

combined_df = combined_df[~combined_df['program'].astype('str').str.endswith(".o")]

if args.num_to_use is None:
    num_rows = combined_df.shape[0]
    df_to_split = combined_df
else:
    num_rows = int(args.num_to_use )
    df_to_split = combined_df.iloc[:num_rows]

# %%
print(df_to_split)
print("Malware amount: ", df_to_split['is_malware'].sum())

train, test, valid = np.split(df_to_split, [int(args.train_amount*num_rows),
                                            int((args.train_amount+args.test_amount)*num_rows)])
# Out:
#                                                     name  is_malware    size  \
# 0      x86__64__lsb__unix-system-v__gcc-9.3.0__O1__no...           0   36208
# 1      x86__64__lsb__unix-system-v__gcc-9.1.0__Os__no...           0   34184
# 2      x86__64__lsb__unix-system-v__gcc-4.9.0__O3__un...           0   67368
# 3      x86__64__lsb__unix-system-v__llvm-obfuscator-3...           0  225064
# 4      x86__64__lsb__unix-system-v__llvm-obfuscator-3...           0   60464
# ...                                                  ...         ...     ...
# 39964  x86__64__lsb__unix-system-v__gcc-7.1.0__O0__no...           0   26424
# 39965  x86__64__lsb__unix-system-v__llvm-obfuscator-4...           0   57168
# 39966  x86__64__lsb__unix-system-v__gcc-7.1.0__O3__no...           0   11280
# 39967  x86__64__lsb__unix-system-v__gcc-8.1.0__O2__no...           0   71744
# 39968  x86__64__lsb__unix-system-v__clang-3.9.0__O2__...           0   88752
#
#       architecture address_size endianness            ABI  \
# 0              x86           64        lsb  unix-system-v
# 1              x86           64        lsb  unix-system-v
# 2              x86           64        lsb  unix-system-v
# 3              x86           64        lsb  unix-system-v
# 4              x86           64        lsb  unix-system-v
# ...            ...          ...        ...            ...
# 39964          x86           64        lsb  unix-system-v
# 39965          x86           64        lsb  unix-system-v
# 39966          x86           64        lsb  unix-system-v
# 39967          x86           64        lsb  unix-system-v
# 39968          x86           64        lsb  unix-system-v
#
#                compiler_used optimization_level obfuscation        stripped  \
# 0                  gcc-9.3.0                 O1      no-obf      unstripped
# 1                  gcc-9.1.0                 Os      no-obf      unstripped
# 2                  gcc-4.9.0                 O3  unstripped  coreutils-8.30
# 3      llvm-obfuscator-3.6.1                 O0    mllvmsub      unstripped
# 4      llvm-obfuscator-3.6.1                 O2    mllvmbcf      unstripped
# ...                      ...                ...         ...             ...
# 39964              gcc-7.1.0                 O0      no-obf      unstripped
# 39965  llvm-obfuscator-4.0.1                 Os    mllvmbcf      unstripped
# 39966              gcc-7.1.0                 O3      no-obf      unstripped
# 39967              gcc-8.1.0                 O2      no-obf      unstripped
# 39968            clang-3.9.0                 O2      no-obf      unstripped
#
#                package    program
# 0       coreutils-8.30     whoami
# 1       coreutils-8.30       echo
# 2             realpath       None
# 3       coreutils-8.30  sha512sum
# 4      util-linux-2.33    setterm
# ...                ...        ...
# 39964  util-linux-2.33    addpart
# 39965   coreutils-8.30     printf
# 39966  util-linux-2.33     findfs
# 39967   coreutils-8.30       stty
# 39968   coreutils-8.30      touch
#
# [39521 rows x 13 columns]
# Malware amount:  711

# %%
train.to_csv("Train_ELF_Dataset.csv",index=False)
malware_amount = train['is_malware'].sum()
print("Train Benignware amount: " + str( train.shape[0] - malware_amount) + "\t\t Malware amount: " + str(malware_amount))
# Out:
# Train Benignware amount: 29115		 Malware amount: 525

# %%
test.to_csv("Test_ELF_Dataset.csv",index=False)
malware_amount = test['is_malware'].sum()
print("Test Benignware amount: " + str( test.shape[0] - malware_amount) + "\t\t Malware amount: " + str(malware_amount))
# Out:
# Test Benignware amount: 5823		 Malware amount: 105

# %%
valid.to_csv("Valid_ELF_Dataset.csv",index=False)
malware_amount = valid['is_malware'].sum()
print("Validation Benignware amount: " + str( valid.shape[0] - malware_amount) + "\t\t Malware amount: " + str(malware_amount))
# Out:
# Validation Benignware amount: 3872		 Malware amount: 81

# %%
train_equal = reduce_non_malware_to_same_amount(train)
test_equal = reduce_non_malware_to_same_amount(test)
valid_equal = reduce_non_malware_to_same_amount(valid)

# %%
train_equal.iloc[:,0:2].to_csv("TrainEven_ELF_Dataset.csv",header=False,index=False)
test_equal.iloc[:,0:2].to_csv("TestEven_ELF_Dataset.csv",header=False,index=False)
valid_equal.iloc[:,0:2].to_csv("ValidEven_ELF_Dataset.csv",header=False,index=False)

# %%
train_equal.to_csv("TrainEven_Full_ELF_Dataset.csv")
test_equal.to_csv("TestEven_Full_ELF_Dataset.csv")
valid_equal.to_csv("ValidEven_Full_ELF_Dataset.csv")

# %% [markdown]
# x86__64__lsb__unix-system-v__gcc-9.3.0__O1__no-obf__unstripped__Mirai-vanilla__bot

# %%
train_equal[train_equal['name'].str.contains("x86__64__lsb__unix-system-v__gcc-9.3.0__O1__no-obf__unstripped__Mirai-vanilla__bot")]
# Out:
#                                                     name  is_malware   size  \
# 26993  x86__64__lsb__unix-system-v__gcc-9.3.0__O1__no...           1  55504
#
#       architecture address_size endianness            ABI compiler_used  \
# 26993          x86           64        lsb  unix-system-v     gcc-9.3.0
#
#       optimization_level obfuscation    stripped        package program
# 26993                 O1      no-obf  unstripped  Mirai-vanilla     bot

# %%
train_equal_minus_one = train_equal[~train_equal['name'].str.contains("x86__64__lsb__unix-system-v__gcc-9.3.0__O1__no-obf__unstripped__Mirai-vanilla__bot")]
train_equal_minus_one
# Out:
#                                                     name  is_malware    size  \
# 340    x86__64__lsb__unix-system-v__gcc-8.1.0__O2__no...           0  150392
# 186    x86__64__lsb__unix-system-v__llvm-obfuscator-3...           0   37216
# 20360  x86__64__lsb__unix-system-v__gcc-7.4.0__O3__no...           1   56944
# 13906  x86__64__lsb__unix-system-v__gcc-4.9.4__O0__no...           1   72664
# 25     x86__64__lsb__unix-system-v__clang-5.0.1__O2__...           0   44800
# ...                                                  ...         ...     ...
# 29773  x86__64__lsb__unix-system-v__clang-3.8.0__O1__...           1   19648
# 246    x86__64__lsb__unix-system-v__llvm-obfuscator-4...           0   44112
# 250    x86__64__lsb__unix-system-v__gcc-7.1.0__O3__no...           0   56664
# 3733   x86__64__lsb__unix-system-v__clang-5.0.1__O3__...           1   63400
# 134    x86__64__lsb__unix-system-v__gcc-8.1.0__Os__no...           0   41584
#
#       architecture address_size endianness            ABI  \
# 340            x86           64        lsb  unix-system-v
# 186            x86           64        lsb  unix-system-v
# 20360          x86           64        lsb  unix-system-v
# 13906          x86           64        lsb  unix-system-v
# 25             x86           64        lsb  unix-system-v
# ...            ...          ...        ...            ...
# 29773          x86           64        lsb  unix-system-v
# 246            x86           64        lsb  unix-system-v
# 250            x86           64        lsb  unix-system-v
# 3733           x86           64        lsb  unix-system-v
# 134            x86           64        lsb  unix-system-v
#
#                compiler_used optimization_level        obfuscation  \
# 340                gcc-8.1.0                 O2             no-obf
# 186    llvm-obfuscator-3.4.0                 O1  mllvmsub_mllvmbcf
# 20360              gcc-7.4.0                 O3             no-obf
# 13906              gcc-4.9.4                 O0             no-obf
# 25               clang-5.0.1                 O2             no-obf
# ...                      ...                ...                ...
# 29773            clang-3.8.0                 O1             no-obf
# 246    llvm-obfuscator-4.0.1                 O3  mllvmsub_mllvmbcf
# 250                gcc-7.1.0                 O3             no-obf
# 3733             clang-5.0.1                 O3             no-obf
# 134                gcc-8.1.0                 Os             no-obf
#
#          stripped            package       program
# 340    unstripped    util-linux-2.33        sfdisk
# 186    unstripped     coreutils-8.30          true
# 20360  unstripped       BASHLITE-1.0        client
# 13906  unstripped      Mirai-vanilla           bot
# 25     unstripped     coreutils-8.30          kill
# ...           ...                ...           ...
# 29773  unstripped  BASHLITE-lizkebab        server
# 246    unstripped    util-linux-2.33  scriptreplay
# 250    unstripped     coreutils-8.30           pwd
# 3733   unstripped      Mirai-vanilla           bot
# 134    unstripped     coreutils-8.30        printf
#
# [1049 rows x 13 columns]

# %%
train_equal_minus_mirai_bot = train_equal[~train_equal['name'].str.contains("Mirai-vanilla__bot")]
train_equal_minus_mirai_bot
# Out:
#                                                     name  is_malware    size  \
# 340    x86__64__lsb__unix-system-v__gcc-8.1.0__O2__no...           0  150392
# 186    x86__64__lsb__unix-system-v__llvm-obfuscator-3...           0   37216
# 20360  x86__64__lsb__unix-system-v__gcc-7.4.0__O3__no...           1   56944
# 25     x86__64__lsb__unix-system-v__clang-5.0.1__O2__...           0   44800
# 13976  x86__64__lsb__unix-system-v__gcc-4.9.0__Os__no...           1   39424
# ...                                                  ...         ...     ...
# 1501   x86__64__lsb__unix-system-v__gcc-8.4.0__O0__no...           1   35816
# 29773  x86__64__lsb__unix-system-v__clang-3.8.0__O1__...           1   19648
# 246    x86__64__lsb__unix-system-v__llvm-obfuscator-4...           0   44112
# 250    x86__64__lsb__unix-system-v__gcc-7.1.0__O3__no...           0   56664
# 134    x86__64__lsb__unix-system-v__gcc-8.1.0__Os__no...           0   41584
#
#       architecture address_size endianness            ABI  \
# 340            x86           64        lsb  unix-system-v
# 186            x86           64        lsb  unix-system-v
# 20360          x86           64        lsb  unix-system-v
# 25             x86           64        lsb  unix-system-v
# 13976          x86           64        lsb  unix-system-v
# ...            ...          ...        ...            ...
# 1501           x86           64        lsb  unix-system-v
# 29773          x86           64        lsb  unix-system-v
# 246            x86           64        lsb  unix-system-v
# 250            x86           64        lsb  unix-system-v
# 134            x86           64        lsb  unix-system-v
#
#                compiler_used optimization_level        obfuscation  \
# 340                gcc-8.1.0                 O2             no-obf
# 186    llvm-obfuscator-3.4.0                 O1  mllvmsub_mllvmbcf
# 20360              gcc-7.4.0                 O3             no-obf
# 25               clang-5.0.1                 O2             no-obf
# 13976              gcc-4.9.0                 Os             no-obf
# ...                      ...                ...                ...
# 1501               gcc-8.4.0                 O0             no-obf
# 29773            clang-3.8.0                 O1             no-obf
# 246    llvm-obfuscator-4.0.1                 O3  mllvmsub_mllvmbcf
# 250                gcc-7.1.0                 O3             no-obf
# 134                gcc-8.1.0                 Os             no-obf
#
#          stripped            package       program
# 340    unstripped    util-linux-2.33        sfdisk
# 186    unstripped     coreutils-8.30          true
# 20360  unstripped       BASHLITE-1.0        client
# 25     unstripped     coreutils-8.30          kill
# 13976  unstripped     lightaidra-1.0    lightaidra
# ...           ...                ...           ...
# 1501   unstripped      Mirai-vanilla        loader
# 29773  unstripped  BASHLITE-lizkebab        server
# 246    unstripped    util-linux-2.33  scriptreplay
# 250    unstripped     coreutils-8.30           pwd
# 134    unstripped     coreutils-8.30        printf
#
# [972 rows x 13 columns]

# %%
train_equal_minus_one.iloc[:,0:2].to_csv("TrainEven_Minus-One_ELF_Dataset.csv",header=False,index=False)
train_equal_minus_mirai_bot.iloc[:,0:2].to_csv("TrainEven_Minus-Mirai-Bot_ELF_Dataset.csv",header=False,index=False)

# %%
size_in_kb = combined_df['size'].div(1024)

# %%
percentiles = size_in_kb.describe(percentiles=[0.5,0.7,0.9,0.95,0.98,0.99])
percentiles
# Out:
# count    39521.000000
# mean        73.673964
# std         96.080706
# min          7.765625
# 50%         49.757812
# 70%         68.835938
# 90%        129.226562
# 95%        180.257812
# 98%        389.857812
# 99%        481.285938
# max       2066.523438
# Name: size, dtype: float64

# %%
size_in_kb.plot(kind='hist',bins=100)
plt.ylabel("Occurrences")
plt.xlabel("Size of ELF Executable in Dataset (KiloBytes)")
plt.title("Histogram of size of ELF Executables in Labeled Elfs Dataset")
plt.axvline(percentiles['90%'],color = 'red',linestyle='dashed',linewidth=0.8)
plt.axvline(percentiles['95%'],color = 'blue',linestyle='dashed',linewidth=0.8)
plt.axvline(percentiles['98%'],color = 'green',linestyle='dashed',linewidth=0.8)
plt.axvline(percentiles['99%'],color = 'orange',linestyle='dashed',linewidth=0.8)
plt.legend(['File Counts',
            '90th percentile %.0f KB'%(percentiles['90%']),
            '95th percentile %.0f KB'%(percentiles['95%']),
            '98th percentile %.0f KB'%(percentiles['98%']),
            '99th percentile %.0f KB'%(percentiles['99%']),
           ])
plt.show()

# %%
size_in_kb.max()
# Out:
# 2066.5234375

# %%
combined_df_kb = combined_df
combined_df_kb['size'] = combined_df_kb['size'].div(1024)
malware_groups = combined_df_kb.groupby('is_malware')
malware_groups['size'].plot(kind='hist',bins=100)
# Out:
# is_malware
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: size, dtype: object

# %%
percentiles = malware_groups.get_group(1)['size'].describe(percentiles=[0.5,0.7,0.9,0.95,0.98,0.99])
percentiles
# Out:
# count    711.000000
# mean      38.104650
# std       18.008464
# min       16.054688
# 50%       38.031250
# 70%       45.148438
# 90%       54.890625
# 95%       62.101562
# 98%       78.760937
# 99%       92.376562
# max      204.296875
# Name: size, dtype: float64

# %%
malware_groups.get_group(1)['size'].plot(kind='hist',bins=100)
plt.ylabel("Occurrences")
plt.xlabel("Size of ELF Malware Executable in Dataset (KiloBytes)")
plt.title("Histogram of size of ELF Malware Executables in Labeled Elfs Dataset")
plt.axvline(percentiles['90%'],color = 'red',linestyle='dashed',linewidth=0.8)
plt.axvline(percentiles['95%'],color = 'blue',linestyle='dashed',linewidth=0.8)
plt.axvline(percentiles['98%'],color = 'green',linestyle='dashed',linewidth=0.8)
plt.axvline(percentiles['99%'],color = 'orange',linestyle='dashed',linewidth=0.8)
plt.legend(['File Counts',
            '90th percentile %.0f KB'%(percentiles['90%']),
            '95th percentile %.0f KB'%(percentiles['95%']),
            '98th percentile %.0f KB'%(percentiles['98%']),
            '99th percentile %.0f KB'%(percentiles['99%']),
           ])
plt.show()

# %%
train_equal_minus_mirai_bot.shape
# Out:
# (972, 13)

# %%
train_equal_minus_all_three = train_equal_minus_mirai_bot[~train_equal_minus_mirai_bot['name'].str.contains("lightaidra-1.0__lightaidra")]

# %%
train_equal_minus_all_three = train_equal_minus_all_three[~train_equal_minus_all_three['name'].str.contains("BASHLITE-lizkebab__client")]

# %%
train_equal_minus_three = train_equal_minus_one[~train_equal_minus_one['name'].str.contains("x86__64__lsb__unix-system-v__gcc-4.9.0__O2__no-obf__unstripped__lightaidra-1.0__lightaidra")]
train_equal_minus_three = train_equal_minus_three[~train_equal_minus_three['name'].str.contains("x86__64__lsb__unix-system-v__clang-5.0.1__Os__no-obf__unstripped__BASHLITE-lizkebab__client")]
train_equal_minus_three
# Out:
#                                                     name  is_malware    size  \
# 340    x86__64__lsb__unix-system-v__gcc-8.1.0__O2__no...           0  150392
# 186    x86__64__lsb__unix-system-v__llvm-obfuscator-3...           0   37216
# 20360  x86__64__lsb__unix-system-v__gcc-7.4.0__O3__no...           1   56944
# 13906  x86__64__lsb__unix-system-v__gcc-4.9.4__O0__no...           1   72664
# 25     x86__64__lsb__unix-system-v__clang-5.0.1__O2__...           0   44800
# ...                                                  ...         ...     ...
# 29773  x86__64__lsb__unix-system-v__clang-3.8.0__O1__...           1   19648
# 246    x86__64__lsb__unix-system-v__llvm-obfuscator-4...           0   44112
# 250    x86__64__lsb__unix-system-v__gcc-7.1.0__O3__no...           0   56664
# 3733   x86__64__lsb__unix-system-v__clang-5.0.1__O3__...           1   63400
# 134    x86__64__lsb__unix-system-v__gcc-8.1.0__Os__no...           0   41584
#
#       architecture address_size endianness            ABI  \
# 340            x86           64        lsb  unix-system-v
# 186            x86           64        lsb  unix-system-v
# 20360          x86           64        lsb  unix-system-v
# 13906          x86           64        lsb  unix-system-v
# 25             x86           64        lsb  unix-system-v
# ...            ...          ...        ...            ...
# 29773          x86           64        lsb  unix-system-v
# 246            x86           64        lsb  unix-system-v
# 250            x86           64        lsb  unix-system-v
# 3733           x86           64        lsb  unix-system-v
# 134            x86           64        lsb  unix-system-v
#
#                compiler_used optimization_level        obfuscation  \
# 340                gcc-8.1.0                 O2             no-obf
# 186    llvm-obfuscator-3.4.0                 O1  mllvmsub_mllvmbcf
# 20360              gcc-7.4.0                 O3             no-obf
# 13906              gcc-4.9.4                 O0             no-obf
# 25               clang-5.0.1                 O2             no-obf
# ...                      ...                ...                ...
# 29773            clang-3.8.0                 O1             no-obf
# 246    llvm-obfuscator-4.0.1                 O3  mllvmsub_mllvmbcf
# 250                gcc-7.1.0                 O3             no-obf
# 3733             clang-5.0.1                 O3             no-obf
# 134                gcc-8.1.0                 Os             no-obf
#
#          stripped            package       program
# 340    unstripped    util-linux-2.33        sfdisk
# 186    unstripped     coreutils-8.30          true
# 20360  unstripped       BASHLITE-1.0        client
# 13906  unstripped      Mirai-vanilla           bot
# 25     unstripped     coreutils-8.30          kill
# ...           ...                ...           ...
# 29773  unstripped  BASHLITE-lizkebab        server
# 246    unstripped    util-linux-2.33  scriptreplay
# 250    unstripped     coreutils-8.30           pwd
# 3733   unstripped      Mirai-vanilla           bot
# 134    unstripped     coreutils-8.30        printf
#
# [1047 rows x 13 columns]

# %%
train_equal_minus_three.iloc[:,0:2].to_csv("TrainEven_Minus-Three_ELF_Dataset.csv",header=False,index=False)
train_equal_minus_all_three.iloc[:,0:2].to_csv("TrainEven_Minus-All-Three_ELF_Dataset.csv",header=False,index=False)
